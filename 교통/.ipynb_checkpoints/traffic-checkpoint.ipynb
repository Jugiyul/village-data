# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] ='Malgun Gothic' 
plt.rcParams['axes.unicode_minus'] =False

warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('2025년_버스노선별_정류장별_시간대별_승하차_인원_정보(02월).csv',encoding='cp949')
df2 = pd.read_csv('서울교통공사_지하철혼잡도정보_20241231 (1).csv',encoding='cp949')
df3 = pd.read_csv('서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv',encoding='cp949')
df4 = pd.read_csv('ES1004AV00101YY2400_csv.csv',encoding='utf8')
d_master = pd.read_csv('서울시 읍면동마스터 정보.csv',encoding='cp949')
d_subway = pd.read_csv('서울시 행정동별 지하철 총 승차 승객수 정보.csv',encoding='cp949')
gu_s_info = pd.read_csv('서울교통공사_자치구별지하철역정보_20250317.CSV',encoding='cp949')
display(df1.tail(), df2.tail(), df3.tail(), df4.tail(),d_master.tail(),d_subway.tail(),gu_s_info.tail())
# Out:
#          사용년월  노선번호                 노선명  표준버스정류장ID 버스정류장ARS번호  \
# 41839  202502  9404     9404번(분당구미~신사역)  999800003          ~
# 41840  202502  9404     9404번(분당구미~신사역)  999800004          ~
# 41841  202502  9409   9409번(구미동차고지~신사역)  999800004          ~
# 41842  202502  9707  9707번(고양 가좌동~영등포역)  999800005          ~
# 41843  202502   707       707번(가좌동~서울역)  999800005          ~
#
#                         역명  00시승차총승객수  00시하차총승객수  1시승차총승객수  1시하차총승객수  ...  \
# 41839  구미동차고지(기점가상)(00001)          0          1         0         2  ...
# 41840  구미동차고지(종점가상)(00062)          0          5         0         6  ...
# 41841  구미동차고지(종점가상)(00088)          0          0         0         1  ...
# 41842   가좌동종점(종점가상)(00078)          0          0         0         9  ...
# 41843   가좌동종점(종점가상)(00127)          0         12         0         8  ...
#
#        20시하차총승객수  21시승차총승객수  21시하차총승객수  22시승차총승객수  22시하차총승객수  23시승차총승객수  \
# ...

# %%
# df1 2025년_버스노선별_정류장별_시간대별_승하차_인원_정보(02월).csv 
# 승차 총 승객수, 하차 총 승객수 
# 버스정류장 ARS번호 앞 두자리가 구를 의미
# 자치구 열 생성

# %%
# d_subway 서울시 행정동별 지하철 총 승차 승객수 정보.csv
# d_master 서울시 읍면동마스터 정보.csv
# 행정동 id > 행정동 명칭 변환
# 승객 수 sum

# %%
# 환승 편의성 지표 ES1004AV00101YY2400_csv.csv
# LEGALDONG_CD 동별
# TKCAR_TRFC_QTY : 승차 통행량
# AVE_TRAF_NMTM : 평균환승횟수
# AVE_TRAF_WAIT_TM : 평균환승대기시간
# PBTS_TRAF_TRFC_RATE : 대중교통환승통행비율율
df4
# Out:
#        DATA_STRD_YR   LTTC_ID  CTPR_CD  SIGNGU_CD  LEGALDONG_CD  \
# 0              2023  다바83b17b     30.0    30200.0  3.020011e+09
# 1              2023  다사21b42a     28.0    28110.0  2.811014e+09
# 2              2023  마라42b89b     26.0    26470.0  2.647010e+09
# 3              2023  다사29a38a     28.0    28177.0  2.817711e+09
# 4              2023  다바68b69a     44.0    44131.0  4.413112e+09
# ...             ...       ...      ...        ...           ...
# 52656          2023  다바84a53a     43.0    43113.0  4.311332e+09
# 52657          2023  마바67a57b     47.0    47930.0  4.793036e+09
# 52658          2023  라사28a72a     51.0    51110.0  5.111032e+09
# 52659          2023  다바99b90a     43.0    43770.0  4.377035e+09
# 52660          2023  라사72b21a     51.0    51750.0  5.175036e+09
#
#        CENSUS_BNDR_CTPR_CD  CENSUS_BNDR_SIGNGU_CD  CENSUS_BNDR_EMD_CD  \
# 0                       25                  25040            25040640
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
