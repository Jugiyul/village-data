# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] ='Malgun Gothic' 
plt.rcParams['axes.unicode_minus'] =False

warnings.filterwarnings('ignore')

# %%
kp = pd.read_csv('행정동 단위 서울 생활인구(내국인).csv',encoding='cp949')
lfp = pd.read_csv('행정동 단위 서울 생활인구(장기체류 외국인).csv',encoding='cp949')
sfp = pd.read_csv('행정동 단위 서울 생활인구(단기체류 외국인).csv',encoding='cp949')
fp = pd.read_excel('2.5. 등록외국인(읍면동, 연령별) 현황(12월말).xlsx')
df = pd.read_csv('서울시 상권분석서비스(길단위인구-행정동).csv',encoding='cp949')
display(kp.tail(), lfp.tail(), sfp.tail(), fp.tail(),df.tail())
# Out:
#            기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 559675  20250208     23  11740650  26535.1176       999.7084         346.7861
# 559676  20250208     23  11740660  29725.3880       801.0738         481.5242
# 559677  20250208     23  11740685  63937.3548      1929.0310         932.8135
# 559678  20250208     23  11740690  24377.4722      1193.4424         904.5068
# 559679  20250208     23  11740700  27325.1488      1242.4217         626.7447
#
#         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# 559675         488.4498         616.0761        1159.7368        1199.2401
# 559676         766.3624        1009.9131        1047.2753        1114.9809
# 559677        1290.5082        1664.0926        2221.8578        2525.2668
# 559678         698.5737         378.5826         397.0884         725.5772
# 559679         775.1713         649.1415         787.9275         894.7606
#
# ...

# %%
df.columns
# Out:
# Index(['기준_년분기_코드', '행정동_코드', '행정동_코드_명', '총_유동인구_수', '남성_유동인구_수', '여성_유동인구_수',
#        '연령대_10_유동인구_수', '연령대_20_유동인구_수', '연령대_30_유동인구_수', '연령대_40_유동인구_수',
#        '연령대_50_유동인구_수', '연령대_60_이상_유동인구_수', '시간대_00_06_유동인구_수',
#        '시간대_06_11_유동인구_수', '시간대_11_14_유동인구_수', '시간대_14_17_유동인구_수',
#        '시간대_17_21_유동인구_수', '시간대_21_24_유동인구_수', '월요일_유동인구_수', '화요일_유동인구_수',
#        '수요일_유동인구_수', '목요일_유동인구_수', '금요일_유동인구_수', '토요일_유동인구_수', '일요일_유동인구_수'],
#       dtype='object')

# %%
df = pd.read_csv('seoul_purpose_admdong3_final_20250228.csv',encoding='utf-8')
df
# Out:
#           o_admdong_cd d_admdong_cd  st_time_cd  fns_time_cd in_forn_div_nm  \
# 0           11110515.0   11110515.0           0            0          단기외국인
# 1           11110515.0   11110515.0           0            0            내국인
# 2           11110515.0   11110515.0           0            0            내국인
# 3           11110515.0   11110515.0           0            0            내국인
# 4           11110515.0   11110530.0           0            0          단기외국인
# ...                ...          ...         ...          ...            ...
# 11653966    51820330.0   41650250.0          23           23          장기외국인
# 11653967           NaN   28185850.0          23           23            내국인
# 11653968           NaN   28185850.0          23           23          단기외국인
# 11653969           NaN   28185850.0          23           23            내국인
# 11653970           NaN   28185860.0          23           23            내국인
#
# ...

# %%
# 이동 목적 : 1: 출근, 2 : 등교, 3: 귀가, 4: 쇼핑, 5: 관광, 6: 병원, 7: 기타
df.columns=['출발행정동','도착행정동','출발시간','도착시간','내외국인구분','국적','이동목적','평균이동거리(m)','평균이동시간(분)','이동인구수','기준연월일']
df
# Out:
#                출발행정동       도착행정동  출발시간  도착시간 내외국인구분    국적  이동목적  평균이동거리(m)  \
# 0         11110515.0  11110515.0     0     0  단기외국인  ㆍ값없음     3     383.55
# 1         11110515.0  11110515.0     0     0    내국인    한국     3     203.10
# 2         11110515.0  11110515.0     0     0    내국인    한국     7     585.20
# 3         11110515.0  11110515.0     0     0    내국인  ㆍ값없음     3     200.00
# 4         11110515.0  11110530.0     0     0  단기외국인  ㆍ값없음     7    1298.10
# ...              ...         ...   ...   ...    ...   ...   ...        ...
# 11653966  51820330.0  41650250.0    23    23  장기외국인   미얀마     7  125515.90
# 11653967         NaN  28185850.0    23    23    내국인  ㆍ값없음     7    2057.30
# 11653968         NaN  28185850.0    23    23  단기외국인  ㆍ값없음     7    1110.20
# 11653969         NaN  28185850.0    23    23    내국인    한국     3    2178.30
# 11653970         NaN  28185860.0    23    23    내국인    한국     7    1360.10
#
#           평균이동시간(분)  이동인구수     기준연월일
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11653971 entries, 0 to 11653970
# Data columns (total 11 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   출발행정동      float64
#  1   도착행정동      object
#  2   출발시간       int64
#  3   도착시간       int64
#  4   내외국인구분     object
#  5   국적         object
#  6   이동목적       int64
#  7   평균이동거리(m)  float64
#  8   평균이동시간(분)  float64
#  9   이동인구수      float64
#  10  기준연월일      int64
# dtypes: float64(4), int64(4), object(3)
# memory usage: 978.0+ MB

# %%
df['출발시간'].value_counts()
# Out:
# 출발시간
# 16      740619
# 15      625404
# 13      593365
# 14      586896
# 12      581007
# 11      535769
# 10      532576
# 6       513146
# 20      429407
# 1800    414881
# 1700    357635
# 21      354429
# 1720    343223
# 800     336893
# 1740    329417
# 740     326501
# 820     311270
# 720     309717
# 1820    294822
# 840     278376
# 700     277523
# 900     273998
# 1840    259224
# 920     255221
# 1900    254413
# 5       254247
# 940     226345
# 1920    218012
# 22      208949
# 1940    196588
# 4       111848
# 1        89825
# 2        72693
# 3        70551
# 0        53120
# 23       36061
# Name: count, dtype: int64

# %%
df['이동목적'].value_counts()
# Out:
# 이동목적
# 7    5368725
# 3    3869013
# 1    2145002
# 2     170806
# 4      65489
# 6      26742
# 5       8194
# Name: count, dtype: int64

# %%
df2=df.loc[(df['출발시간'].between(5,10)) & (df['이동목적'] !=3),:].reset_index(drop=True)
df2
# Out:
#               출발행정동       도착행정동  출발시간  도착시간 내외국인구분    국적  이동목적      평균이동거리(m)  \
# 0        11110515.0  11110515.0     5     5    내국인    한국     1     828.000000
# 1        11110515.0  11110515.0     5     5    내국인  ㆍ값없음     7     553.250000
# 2        11110515.0  11110515.0     5     5  단기외국인  ㆍ값없음     7     491.250000
# 3        11110515.0  11110515.0     5     5    내국인    한국     7     253.700000
# 4        11110515.0  11110530.0     5     5    내국인  ㆍ값없음     7    1012.033333
# ...             ...         ...   ...   ...    ...   ...   ...            ...
# 1144708  41610253.0    41610253    10    23  단기외국인  ㆍ값없음     7     832.200000
# 1144709  41610580.0    41610580    10    23  단기외국인  ㆍ값없음     7    1234.900000
# 1144710  44210360.0    41220256    10    23  단기외국인  ㆍ값없음     7   35852.200000
# 1144711  47111570.0    41465540    10    23  단기외국인  ㆍ값없음     7  251152.200000
# 1144712  47770310.0    41550380    10    23    내국인  ㆍ값없음     7  215543.200000
#
# ...

# %%
df3=df2.loc[(df2['출발행정동'].notna()) & (df2['도착행정동'].notna())].reset_index(drop=True)
df3=df3.astype({'출발행정동':'int','도착행정동':'int'})
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 df3=df2.loc[(df2['출발행정동'].notna()) & (df2['도착행정동'].notna())].reset_index(drop=True)
# ----> 2 df3=df3.astype({'출발행정동':'int','도착행정동':'int'})
#       3 df3
#
# File c:\Users\tldjs\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6620, in NDFrame.astype(self, dtype, copy, errors)
#    6618 else:
#    6619     try:
# -> 6620         res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    6621     except ValueError as ex:
#    6622         ex.args = (
#    6623             f"{ex}: Error while type casting for column '{col_name}'",
#    6624         )
#
# File c:\Users\tldjs\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
# ...

# %%
df2['도착행정동'].value_counts()
# Out:
# 도착행정동
# 11560540.0    10682
# 28110628.0     9197
# 11680640.0     9112
# 11110615.0     8297
# 11140550.0     7455
#               ...
# 46890360          1
# 44180320          1
# 48890360          1
# 29140660          1
# 52210460          1
# Name: count, Length: 5944, dtype: int64
